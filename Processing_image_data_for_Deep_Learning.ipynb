# %%
# getting an image using web get

# !wget 'https://tse2.mm.bing.net/th?id=OIP.U4tAcfjZaKnrLJ8km700QwHaE7&pid=Api&P=0&h=180.jpg'
# Out:
# --2025-01-03 14:26:09--  https://tse2.mm.bing.net/th?id=OIP.U4tAcfjZaKnrLJ8km700QwHaE7&pid=Api&P=0&h=180.jpg
# Resolving tse2.mm.bing.net (tse2.mm.bing.net)... 150.171.27.10, 150.171.28.10, 2620:1ec:33::10, ...
# Connecting to tse2.mm.bing.net (tse2.mm.bing.net)|150.171.27.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16564 (16K) [image/jpeg]
# Saving to: ‘th?id=OIP.U4tAcfjZaKnrLJ8km700QwHaE7&pid=Api&P=0&h=180.jpg’
#
# th?id=OIP.U4tAcfjZa 100%[===================>]  16.18K  --.-KB/s    in 0s
#
# 2025-01-03 14:26:09 (158 MB/s) - ‘th?id=OIP.U4tAcfjZaKnrLJ8km700QwHaE7&pid=Api&P=0&h=180.jpg’ saved [16564/16564]

# %% [markdown]
# **Libraries that can be used for image processing:**
#
# 1. matplotlib.image
#
# 2. Pillow
#
# 3. OpenCV(cv2)

# %%
# importing the image module from matplotlib library

import matplotlib.image as npimg
import matplotlib.pyplot as plt

# %%
# loading an image through matplotlib.image module

img = npimg.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (315, 474, 3)

# %%
print(img)
# Out:
# [[[141 182  15]
#   [141 185  14]
#   [141 185  10]
#   ...
#   [137 154   0]
#   [139 156   2]
#   [139 156   2]]
#
#  [[144 183  16]
#   [142 184  14]
#   [142 186  11]
#   ...
#   [136 153   0]
#   [139 156   2]
#   [139 156   2]]
#
#  [[138 175   7]
#   [136 175   4]
#   [134 177   2]
#   ...
#   [135 152   0]
#   [138 155   1]
#   [138 155   1]]
#
#  ...
#
#  [[ 74  69  37]
#   [ 59  54  22]
#   [ 60  54  22]
#   ...
#   [128 104  40]
#   [130 106  42]
#   [133 109  45]]
#
#  [[ 84  79  47]
#   [ 67  62  30]
#   [ 64  58  26]
#   ...
#   [131 107  45]
#   [140 116  54]
#   [142 118  54]]
#
#  [[ 93  87  55]
#   [ 73  67  35]
#   [ 67  58  27]
#   ...
#   [133 109  47]
#   [139 115  53]
#   [142 118  56]]]

# %%
# displaying the image from numpy array

img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# Resizing the image using Pillow library

# %%
from PIL import Image

# %%
img = Image.open('/content/dog.jpg')
img_resized = img.resize((200, 200))

# %%
img_resized.save('dog_Image_resized.jpg')

# %%
# displaying the image from numpy array

img_res = npimg.imread('/content/dog_Image_resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# **Converting RGB images to Grayscale image using OpenCV**

# %%
# importing OpenCV library

import cv2

# %%
img = cv2.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (315, 474, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (315, 474)

# %%
from google.colab.patches import cv2_imshow

# %%
# display the image

cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=474x315>

# %%
# saving the grayscale image

cv2.imwrite('dog_grayscale_image.jpg', grayscale_image)
# Out:
# True
